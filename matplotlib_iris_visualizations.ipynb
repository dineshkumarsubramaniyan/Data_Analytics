# %% [markdown]
# # 📊 Matplotlib Visualization with Iris Dataset
# This notebook demonstrates various Matplotlib visualizations using the Iris dataset.

# %%
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.datasets import load_iris

# Load the dataset
iris = load_iris()
df = pd.DataFrame(data=iris.data, columns=iris.feature_names)
df['species'] = pd.Categorical.from_codes(iris.target, iris.target_names)
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#   species
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa

# %% [markdown]
# ## 1️⃣ Line Plot

# %%
plt.plot(df['sepal length (cm)'], label='Sepal Length')
plt.plot(df['sepal width (cm)'], label='Sepal Width')
plt.title("Line Plot of Sepal Dimensions")
plt.xlabel("Index")
plt.ylabel("cm")
plt.legend()
plt.show()

# %% [markdown]
# ## 2️⃣ Bar Plot

# %%
mean_values = df.groupby('species').mean()
mean_values[['petal length (cm)', 'petal width (cm)']].plot(kind='bar')
plt.title("Mean Petal Dimensions by Species")
plt.ylabel("cm")
plt.show()
# Out:
# C:\Users\Dinesh\AppData\Local\Temp\ipykernel_19908\1254941198.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   mean_values = df.groupby('species').mean()

# %% [markdown]
# ## 3️⃣ Scatter Plot

# %%
colors = {'setosa': 'r', 'versicolor': 'g', 'virginica': 'b'}
for species in df['species'].unique():
    subset = df[df['species'] == species]
    plt.scatter(subset['sepal length (cm)'], subset['sepal width (cm)'], label=species, color=colors[species])
plt.title("Scatter Plot of Sepal Dimensions")
plt.xlabel("Sepal Length (cm)")
plt.ylabel("Sepal Width (cm)")
plt.legend()
plt.show()

# %% [markdown]
# ## 4️⃣ Histogram

# %%
plt.hist(df['petal length (cm)'], bins=20, color='orange', edgecolor='black')
plt.title("Histogram of Petal Length")
plt.xlabel("Petal Length (cm)")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ## 5️⃣ Box Plot

# %%
df.boxplot(column=['sepal length (cm)', 'sepal width (cm)'])
plt.title("Boxplot of Sepal Dimensions")
plt.ylabel("cm")
plt.show()

# %% [markdown]
# ## 6️⃣ Pie Chart

# %%
species_counts = df['species'].value_counts()
plt.pie(species_counts, labels=species_counts.index, autopct='%1.1f%%', startangle=140)
plt.title("Species Distribution")
plt.show()

# %% [markdown]
# ## 7️⃣ Subplots

# %%
fig, axs = plt.subplots(1, 2, figsize=(12, 4))
axs[0].hist(df['sepal length (cm)'], color='skyblue')
axs[0].set_title('Sepal Length')
axs[1].hist(df['sepal width (cm)'], color='salmon')
axs[1].set_title('Sepal Width')
plt.suptitle("Histograms of Sepal Dimensions")
plt.tight_layout()
plt.show()
